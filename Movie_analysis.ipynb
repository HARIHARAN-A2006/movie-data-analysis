# %% [markdown]
# # 🎬 Movie Data Analysis using Python
#
# ## A Data Cleaning and Exploratory Data Analysis Project
#
# **Prepared by:** Hariharan A
#
# **Department:** Computer Science and Engineering
#
# **Institution:** Bharath Institute of Higher Education and Research
#
# **Tools Used**
# - Python
# - Pandas
# - NumPy
# - Jupyter Notebook
#
# **Dataset**
# Movie Assignment Dataset
#
# ---

# %% [markdown]
# # Project Overview
#
# This project focuses on analyzing a movie dataset using Python. The objective is to clean the dataset, handle missing values, remove irrelevant information, and perform exploratory data analysis (EDA) to extract meaningful insights about movie profitability, ratings, directors, genres, and actors.
#
# The project demonstrates practical applications of Pandas and NumPy for real-world data analysis tasks.

# %% [markdown]
# # Project Objectives
#
# The objectives of this project are:
#
# - Read and inspect the movie dataset.
# - Analyze the structure of the dataset.
# - Handle missing values.
# - Remove unnecessary columns.
# - Remove duplicate records.
# - Calculate movie profits.
# - Identify the highest profitable movies.
# - Find IMDb Top 250 movies.
# - Analyze top-rated directors.
# - Study genre popularity.
# - Compare audience and critic preferences for actors.

# %% [markdown]
# # Step 1: Import Required Libraries
#
# ## Objective
#
# The first step of every data analysis project is importing the necessary Python libraries. These libraries provide functions for handling datasets, performing numerical computations, and suppressing unnecessary warning messages.
#
# The following libraries are used:
#
# - **Pandas** for data manipulation.
# - **NumPy** for numerical operations.
# - **Warnings** to suppress unwanted warning messages.

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# # Step 2: Import the Dataset
#
# ## Objective
#
# The movie dataset is stored in CSV format. In this step, the dataset is imported into a Pandas DataFrame named **movies**. This DataFrame will be used throughout the project for data cleaning and analysis.

# %%
movies = pd.read_csv('Movie+Assignment+Data.csv')

movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## Determine Dataset Dimensions
#
# The shape of the dataset is checked to determine the total number of observations (rows) and attributes (columns).
#
# ## Examine Dataset Information
#
# The information of the dataset is displayed to understand:
#
# - Total number of records
# - Number of columns
# - Data types
# - Missing values
# - Memory usage

# %%
print(movies.shape)
print(movies.info())
# Out:
# (5043, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %% [markdown]
# # Step 3: Missing Value Analysis
#
# ## Objective
#
# Real-world datasets usually contain incomplete information. This step identifies missing values present in each column and calculates the percentage of missing records.
#
# This information helps determine the most appropriate data cleaning strategy.

# %%
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
null_percentage = (movies.isnull().sum() / len(movies)) * 100
null_percentage_rounded = null_percentage.round(2)
null_percentage_rounded
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# # Step 4: Remove Unnecessary Columns
#
# ## Objective
#
# Several columns are not relevant to the objectives of this project. These columns are removed to simplify the dataset and improve processing efficiency.
#
# Removing unnecessary features also reduces memory usage and improves readability.

# %%
movies = movies.drop(['color', 
                      'director_facebook_likes', 
                      'actor_3_facebook_likes', 
                      'actor_1_facebook_likes', 
                      'cast_total_facebook_likes', 
                      'actor_2_facebook_likes', 
                      'duration', 
                      'facenumber_in_poster', 
                      'content_rating', 
                      'country', 
                      'movie_imdb_link', 
                      'aspect_ratio',
                      'plot_keywords',
                      'actor_2_name',
                      'actor_3_name'], 
                       axis = 1)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# # Step 5: Remove Incomplete Records
#
# ## Objective
#
# Rows containing excessive missing values are removed because they provide limited analytical value and may affect the accuracy of the analysis.

# %%
null_percentage = (movies.isnull().sum() / len(movies)) * 100
columns_drop = null_percentage[null_percentage > 5].index.tolist()
movies_cleaned_1 = movies.dropna(subset=columns_drop)
movies_cleaned_1
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies_cleaned_2 = movies_cleaned_1.dropna(thresh = 8)
movies_cleaned_2
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# # Step 6: Handle Remaining Missing Values
#
# ## Objective
#
# Some missing values remain after removing incomplete records. Since English is the dominant language in the dataset, missing values in the language column are replaced with "English".

# %%
movies_cleaned_2['language'] = movies_cleaned_2['language'].fillna('English')
movies_cleaned_2
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# # Step 7: Verify the Cleaned Dataset
#
# ## Objective
#
# After completing the cleaning process, the percentage of retained records is calculated. This helps evaluate how much useful information remains for analysis.

# %%
total_rows = movies.shape[0]
retained_rows = movies_cleaned_2.shape[0]
percentage_retained = (retained_rows / total_rows) * 100
percentage_retained
# Out:
# 77.15645449137418

# %% [markdown]
# # Step 8: Convert Financial Units
#
# ## Objective
#
# The budget and gross revenue values are converted from dollars to millions of dollars to make the values easier to interpret and compare.

# %%
movies_cleaned_2['budget'] = movies_cleaned_2['budget'] / 1_000_000 
movies_cleaned_2['gross'] = movies_cleaned_2['gross'] / 1_000_000  
movies_cleaned_2
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# # Step 9: Profit Analysis
#
# ## Objective
#
# Movie profitability is calculated by subtracting the production budget from the gross revenue.
#
# The calculated profit is stored as a new feature for further analysis.

# %%
movies_cleaned_2['profit'] = movies_cleaned_2['gross'] - movies_cleaned_2['budget']
print(movies_cleaned_2[['budget', 'gross', 'profit']])
# Out:
#         budget       gross      profit
# 0     237.0000  760.505847  523.505847
# 1     300.0000  309.404152    9.404152
# 2     245.0000  200.074175  -44.925825
# 3     250.0000  448.130642  198.130642
# 5     263.7000   73.058679 -190.641321
# ...        ...         ...         ...
# 5033    0.0070    0.424760    0.417760
# 5034    0.0070    0.070071    0.063071
# 5035    0.0070    2.040920    2.033920
# 5037    0.0090    0.004584   -0.004416
# 5042    0.0011    0.085222    0.084122
#
# [3891 rows x 3 columns]

# %% [markdown]
# ## Identify the Most Profitable Movies
#
# The movies are sorted according to profit in descending order to identify the highest profitable movies in the dataset.

# %%
sorted_movies = movies_cleaned_2.sort_values(by='profit', ascending=False)

sorted_movies
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
top10 = movies.iloc[:10, ]
top10
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
# 5     Andrew Stanton                   462.0   73058679.0
# 6          Sam Raimi                   392.0  336530303.0
# 7       Nathan Greno                   324.0  200807262.0
# 8        Joss Whedon                   635.0  458991599.0
# 9        David Yates                   375.0  301956980.0
#
#                                               genres     actor_1_name  \
# 0                    Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                           Action|Adventure|Fantasy      Johnny Depp
# 2                          Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# # Step 10: Remove Duplicate Records
#
# ## Objective
#
# Duplicate records are removed to eliminate redundant observations and improve the reliability of the analysis.

# %%
movies.drop_duplicates(subset = None, keep = 'first', inplace = True)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies_cleaned_2['profit'] = movies_cleaned_2['gross'] - movies_cleaned_2['budget']

sorted_movies = movies_cleaned_2.sort_values(by='profit', ascending=False)
top10 = sorted_movies.head(10)
top10 = top10.drop_duplicates()
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %% [markdown]
# # Step 11: IMDb Top 250 Analysis
#
# ## Objective
#
# Movies are filtered based on IMDb score and user votes to identify the highest-rated movies.
#
# Only movies with more than **25,000 user votes** are considered to ensure ranking reliability.

# %%
IMDb_Top_250 = movies.sort_values(by = 'imdb_score', ascending = False)
IMDb_Top_250 = IMDb_Top_250.loc[IMDb_Top_250.num_voted_users > 25000]
IMDb_Top_250 = IMDb_Top_250.iloc[:250, ]
IMDb_Top_250['Rank'] = range(1,251)
IMDb_Top_250
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 1937         Frank Darabont                   199.0   28341469.0
# 3466   Francis Ford Coppola                   208.0  134821952.0
# 2837   Francis Ford Coppola                   149.0   57300000.0
# 3481                    NaN                    54.0          NaN
# 66        Christopher Nolan                   645.0  533316061.0
# ...                     ...                     ...          ...
# 2937  Franklin J. Schaffner                   112.0          NaN
# 3821     Billy Bob Thornton                   104.0   24475416.0
# 2944        Martin Campbell                   400.0  167007184.0
# 3280         Norman Jewison                    66.0   50000000.0
# 3741           Edgar Wright                   246.0   13464388.0
#
#                             genres        actor_1_name  \
# 1937                   Crime|Drama      Morgan Freeman
# 3466                   Crime|Drama           Al Pacino
# ...

# %%
Top_Foreign_Lang_Film =IMDb_Top_250.loc[IMDb_Top_250['language'] != 'English']
Top_Foreign_Lang_Film
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0   6100000.0
# 4747                    Akira Kurosawa                   153.0    269061.0
# 4029                Fernando Meirelles                   214.0   7563397.0
# 2373                    Hayao Miyazaki                   246.0  10049886.0
# 4921                      Majid Majidi                    46.0    925402.0
# 3870                        Raja Menon                    39.0         NaN
# 4259  Florian Henckel von Donnersmarck                   215.0  11284657.0
# 1298                Jean-Pierre Jeunet                   242.0  33201661.0
# 4105                    Chan-wook Park                   305.0   2181290.0
# 2323                    Hayao Miyazaki                   174.0   2298191.0
# 2970                 Wolfgang Petersen                    96.0  11433134.0
# ...

# %% [markdown]
# # Step 13: Director Performance Analysis
#
# ## Objective
#
# The average IMDb score of each director is calculated to identify directors who consistently produce highly rated movies.

# %%
director = movies.pivot_table(values = 'imdb_score', index = 'director_name', aggfunc = 'mean')
director = director.sort_values(by = 'imdb_score', ascending = False)
director = director.iloc[:10, ]
director
# Out:
#                   imdb_score
# director_name
# John Blanchard           9.5
# Sadyk Sher-Niyaz         8.7
# Cary Bell                8.7
# Mitchell Altieri         8.7
# Mike Mayhall             8.6
# Charles Chaplin          8.6
# Damien Chazelle          8.5
# Raja Menon               8.5
# Majid Majidi             8.5
# Ron Fricke               8.5

# %% [markdown]
# # Step 14: Genre Combination Analysis
#
# ## Objective
#
# Many movies belong to multiple genres.
#
# This analysis separates the primary and secondary genres and identifies genre combinations that generate the highest average gross revenue.

# %%
movies['genres'] = movies['genres'].str.split('|')
movies['genre_1'] = movies['genres'].apply(lambda x: x[0])
movies['genre_2'] = movies['genres'].apply(lambda x : x[1] if len(x) > 1 else x[0])
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                     genres     actor_1_name  \
# 0     [Action, Adventure, Fantasy, Sci-Fi]      CCH Pounder
# 1             [Action, Adventure, Fantasy]      Johnny Depp
# ...

# %%
movies_by_segment =movies_by_segment = movies.groupby(['genre_1', 'genre_2'])

# %%
PopGenre = pd.DataFrame(movies_by_segment['gross'].mean()).sort_values(by = 'gross', ascending = False)
PopGenre.iloc[:5, ]
# Out:
#                             gross
# genre_1   genre_2
# Family    Sci-Fi     4.349495e+08
# Adventure Sci-Fi     2.286278e+08
#           Animation  1.170500e+08
#           Family     1.155375e+08
# Action    Adventure  1.087523e+08

# %% [markdown]
# # Step 15: Actor Popularity Analysis
#
# ## Objective
#
# This analysis compares three well-known actors:
#
# - Meryl Streep
# - Leonardo DiCaprio
# - Brad Pitt
#
# The comparison is based on both critic reviews and user reviews to identify audience and critic preferences.

# %%
Meryl_Streep = movies.loc[movies.actor_1_name == 'Meryl Streep']
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 410     Nancy Meyers                   187.0  112703470.0
# 1106   Curtis Hanson                    42.0   46815748.0
# 1204     Nora Ephron                   252.0   94125426.0
# 1408   David Frankel                   208.0  124732962.0
# 1483  Robert Redford                   227.0   14998070.0
# 1575  Sydney Pollack                    66.0   87100000.0
# 1618   David Frankel                   234.0   63536011.0
# 1674   Carl Franklin                    64.0   23209440.0
# 1752  Stephen Frears                    87.0          NaN
# 1925  Stephen Daldry                   174.0   41597830.0
# 2781  Phyllida Lloyd                   331.0   29959436.0
# 3135   Robert Altman                   211.0   20338609.0
# 3641  Fred Zinnemann                    38.0          NaN
#
#                                           genres  actor_1_name  \
# 410                     [Comedy, Drama, Romance]  Meryl Streep
# ...

# %%
Leo_Caprio = movies.loc[movies.actor_1_name == 'Leonardo DiCaprio']
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 26            James Cameron                   315.0  658672302.0
# 50             Baz Luhrmann                   490.0  144812796.0
# 97        Christopher Nolan                   642.0  292568851.0
# 179   Alejandro G. Iñárritu                   556.0  183635922.0
# 257         Martin Scorsese                   267.0  102608827.0
# 296       Quentin Tarantino                   765.0  162804648.0
# 307            Edward Zwick                   166.0   57366262.0
# 308         Martin Scorsese                   606.0  116866727.0
# 326         Martin Scorsese                   233.0   77679638.0
# 361         Martin Scorsese                   352.0  132373442.0
# 452         Martin Scorsese                   490.0  127968405.0
# 641            Ridley Scott                   238.0   39380442.0
# 911        Steven Spielberg                   194.0  164435221.0
# ...

# %%
Brad_Pitt =movies.loc[movies.actor_1_name == 'Brad Pitt']
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 101           David Fincher                   362.0  127490802.0
# 147       Wolfgang Petersen                   220.0  133228348.0
# 254       Steven Soderbergh                   198.0  125531634.0
# 255              Doug Liman                   233.0  186336103.0
# 382              Tony Scott                   142.0      26871.0
# 400       Steven Soderbergh                   186.0  183405771.0
# 470              David Ayer                   406.0   85707116.0
# 611     Jean-Jacques Annaud                    76.0   37901509.0
# 683           David Fincher                   315.0   37023395.0
# 792         Patrick Gilmore                    98.0   26288320.0
# 940             Neil Jordan                   120.0  105264608.0
# 1490        Terrence Malick                   584.0   13303319.0
# 1722         Andrew Dominik                   273.0    3904982.0
# ...

# %%
Combined = pd.concat([Meryl_Streep, Brad_Pitt, Leo_Caprio])
Combined
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 410            Nancy Meyers                   187.0  112703470.0
# 1106          Curtis Hanson                    42.0   46815748.0
# 1204            Nora Ephron                   252.0   94125426.0
# 1408          David Frankel                   208.0  124732962.0
# 1483         Robert Redford                   227.0   14998070.0
# 1575         Sydney Pollack                    66.0   87100000.0
# 1618          David Frankel                   234.0   63536011.0
# 1674          Carl Franklin                    64.0   23209440.0
# 1752         Stephen Frears                    87.0          NaN
# 1925         Stephen Daldry                   174.0   41597830.0
# 2781         Phyllida Lloyd                   331.0   29959436.0
# 3135          Robert Altman                   211.0   20338609.0
# 3641         Fred Zinnemann                    38.0          NaN
# ...

# %%
groupe_combined = Combined.groupby('actor_1_name')

groupe_combined.size()
# Out:
# actor_1_name
# Brad Pitt            18
# Leonardo DiCaprio    21
# Meryl Streep         13
# dtype: int64

# %% [markdown]
# # Project Results
#
# ## Summary of Findings
#
# The analysis successfully identified:
#
# - Top profitable movies
# - IMDb Top 250 movies
# - Highest-rated directors
# - Popular genre combinations
# - Critic and audience favourite actors
#
# These insights demonstrate the effectiveness of Python for performing real-world exploratory data analysis.

# %% [markdown]
# # Conclusion
#
# This project successfully demonstrates the complete workflow of data cleaning and exploratory data analysis using Python.
#
# The movie dataset was cleaned by handling missing values, removing unnecessary columns, and eliminating duplicate records. Various analytical techniques were then applied to identify profitable movies, top-rated directors, successful genre combinations, and audience preferences.
#
# The project highlights the importance of data preprocessing and exploratory analysis in extracting meaningful business insights from raw datasets.
